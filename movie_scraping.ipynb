# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
username = 'deathproof'
url = f'https://letterboxd.com/{username}/films/page/1/'
data = requests.get(url)

# %%
soup = BeautifulSoup(data.text)

# %%
pages = soup.select('div.pagination')[0]
pages = pages.find_all('a')
n_pages = pages[-1:][0].text
print(n_pages)
# Out:
# 36

# %%
def rating_to_numeric(film_rating_raw):
    stars = film_rating_raw.count('★')
    halves = film_rating_raw.count('½')
    rating_numeric = stars + halves/2
    return rating_numeric

# %%
film_url_list = []
film_name_list = []
film_rating_list = []
for page_idx in range(1, int(n_pages)+1):
    url = f'https://letterboxd.com/{username}/films/page/{page_idx}/'
    data = requests.get(url)
    soup = BeautifulSoup(data.text)
    posters = soup.select('li.poster-container')

    for poster in posters:
        try:
            film_url = poster.find('div', class_='film-poster')['data-film-slug']
            film_url = f'https://letterboxd.com/film/{film_url}'
            film_name = poster.find('img', class_='image')['alt']
            film_rating_raw = poster.find('span', class_='rating').text
            film_rating_numeric = rating_to_numeric(film_rating_raw)

            film_url_list.append(film_url)
            film_name_list.append(film_name)
            film_rating_list.append(film_rating_numeric)
        except:
            continue
df_data = {
    'Title': film_name_list,
    'Rating': film_rating_list,
    'URL': film_url_list
}
rating_df = pd.DataFrame(data=df_data)

# %%
rating_df
# Out:
#                                     Title  Rating  \
# 0                                  Barbie     3.0
# 1                 Insidious: The Red Door     2.0
# 2                        No Hard Feelings     3.0
# 3     Spider-Man: Across the Spider-Verse     4.5
# 4                           Asteroid City     4.0
# ...                                   ...     ...
# 2396                              Dracula     2.5
# 2397                           Metropolis     3.5
# 2398                            Nosferatu     2.5
# 2399                              The Kid     3.0
# 2400          The Cabinet of Dr. Caligari     4.0
#
#                                                     URL
# 0                    https://letterboxd.com/film/barbie
# 1     https://letterboxd.com/film/insidious-the-red-...
# 2     https://letterboxd.com/film/no-hard-feelings-2023
# 3     https://letterboxd.com/film/spider-man-across-...
# 4             https://letterboxd.com/film/asteroid-city
# ...                                                 ...
# 2396                https://letterboxd.com/film/dracula
# 2397             https://letterboxd.com/film/metropolis
# 2398              https://letterboxd.com/film/nosferatu
# 2399                https://letterboxd.com/film/the-kid
# 2400  https://letterboxd.com/film/the-cabinet-of-dr-...
#
# [2401 rows x 3 columns]

# %%
rating_df.URL.values[0]
# Out:
# 'https://letterboxd.com/film/barbie'

# %%
def get_movie_features(urls):
    tab_indices = {
        0: [0],  # only cast box
        1: [0],  # only director crew
        2: [0],  # only studios
        3: [0,1]   # only genres
    }

    all_movie_data = []

    for url in urls:
        data = requests.get(url)
        soup = BeautifulSoup(data.text, 'html.parser')
    
        df_data = {}
        df_data['Title'] = soup.select('h1.headline-1')[0].text
        try:
            duration = soup.select('p.text-link')[0].text
            index_mins = duration.find('mins')
            duration = int(duration[index_mins - 4 : index_mins].strip())
        except ValueError:
            duration = 0
        df_data['Duration'] = duration
        
        for tab, indices in tab_indices.items():
            try:
                df_data[tab] = []
                for index in indices:
                    for group in soup.select('div.tabbed-content-block')[tab].select('div.text-sluglist')[index].find_all('a'):
                        for g in group:
                            if g != 'Show All…':
                                df_data[tab].append(g.text)
            except:
                continue

        key_mapping = {
            0: "Cast",
            1: "Crew",
            2: 'Studios',
            3: 'Genres'
        }

        # Create a new dictionary with renamed keys
        new_dict = {key_mapping.get(key, key): value for key, value in df_data.items()}
        new_dict['URL'] = url
        all_movie_data.append(new_dict)

    df = pd.DataFrame(all_movie_data)
    return df

# %%
movie_features = get_movie_features(rating_df.URL.values)
movie_features
# Out:
#                                     Title  Duration  \
# 0                                  Barbie       114
# 1                 Insidious: The Red Door       107
# 2                        No Hard Feelings       103
# 3     Spider-Man: Across the Spider-Verse       140
# 4                           Asteroid City       105
# ...                                   ...       ...
# 2396                              Dracula        74
# 2397                           Metropolis       149
# 2398                            Nosferatu        94
# 2399                              The Kid        68
# 2400          The Cabinet of Dr. Caligari        78
#
#                                                    Cast  \
# 0     [Margot Robbie, Ryan Gosling, America Ferrera,...
# 1     [Ty Simpkins, Patrick Wilson, Sinclair Daniel,...
# 2     [Jennifer Lawrence, Andrew Barth Feldman, Laur...
# 3     [Shameik Moore, Hailee Steinfeld, Jason Schwar...
# 4     [Jason Schwartzman, Scarlett Johansson, Tom Ha...
# ...                                                 ...
# 2396  [Bela Lugosi, Helen Chandler, David Manners, D...
# 2397  [Gustav Fröhlich, Brigitte Helm, Alfred Abel, ...
# 2398  [Max Schreck, Gustav von Wangenheim, Greta Sch...
# 2399  [Charlie Chaplin, Jackie Coogan, Edna Purvianc...
# 2400  [Werner Krauß, Conrad Veidt, Friedrich Fehér, ...
#
#                                                    Crew  \
# 0                                        [Greta Gerwig]
# 1                                      [Patrick Wilson]
# 2                                     [Gene Stupnitsky]
# 3     [Joaquim Dos Santos, Justin K. Thompson, Kemp ...
# 4                                        [Wes Anderson]
# ...                                                 ...
# 2396                                     [Tod Browning]
# 2397                                       [Fritz Lang]
# 2398                                     [F. W. Murnau]
# 2399                                  [Charlie Chaplin]
# 2400                                     [Robert Wiene]
#
#                                                 Studios  \
# 0     [LuckyChap Entertainment, Heyday Films, NB/GG ...
# 1     [Blumhouse Productions, Stage 6 Films, Screen ...
# 2     [Excellent Cadaver, Odenkirk Provissiero Enter...
# 3     [Columbia Pictures, Sony Pictures Animation, L...
# 4      [American Empirical Pictures, Indian Paintbrush]
# ...                                                 ...
# 2396                               [Universal Pictures]
# 2397                                              [UFA]
# 2398  [Prana-Film GmbH, Jofa-Atelier Berlin-Johannis...
# 2399                      [Charles Chaplin Productions]
# 2400               [Decla Film Gesellschaft Holz & Co.]
#
#                                                  Genres  \
# 0     [fantasy, comedy, adventure, Relationship come...
# 1     [thriller, horror, mystery, Horror, the undead...
# 2     [comedy, romance, Relationship comedy, Crude h...
# 3     [animation, adventure, action, Epic heroes, ac...
# 4     [comedy, drama, Relationship comedy, earth, sc...
# ...                                                 ...
# 2396  [fantasy, drama, horror, Horror, the undead an...
# 2397  [drama, science-fiction, Faith and religion, E...
# 2398  [fantasy, horror, Horror, the undead and monst...
# 2399  [comedy, drama, Relationship comedy, Crude hum...
# 2400  [thriller, crime, drama, horror, Horror, the u...
#
#                                                     URL
# 0                    https://letterboxd.com/film/barbie
# 1     https://letterboxd.com/film/insidious-the-red-...
# 2     https://letterboxd.com/film/no-hard-feelings-2023
# 3     https://letterboxd.com/film/spider-man-across-...
# 4             https://letterboxd.com/film/asteroid-city
# ...                                                 ...
# 2396                https://letterboxd.com/film/dracula
# 2397             https://letterboxd.com/film/metropolis
# 2398              https://letterboxd.com/film/nosferatu
# 2399                https://letterboxd.com/film/the-kid
# 2400  https://letterboxd.com/film/the-cabinet-of-dr-...
#
# [2401 rows x 7 columns]

# %%
df = rating_df.merge(movie_features, on=['Title', 'URL'])
df.head()
# Out:
#                                  Title  Rating  \
# 0                               Barbie     3.0
# 1              Insidious: The Red Door     2.0
# 2                     No Hard Feelings     3.0
# 3  Spider-Man: Across the Spider-Verse     4.5
# 4                        Asteroid City     4.0
#
#                                                  URL  Duration  \
# 0                 https://letterboxd.com/film/barbie       114
# 1  https://letterboxd.com/film/insidious-the-red-...       107
# 2  https://letterboxd.com/film/no-hard-feelings-2023       103
# 3  https://letterboxd.com/film/spider-man-across-...       140
# 4          https://letterboxd.com/film/asteroid-city       105
#
#                                                 Cast  \
# 0  [Margot Robbie, Ryan Gosling, America Ferrera,...
# 1  [Ty Simpkins, Patrick Wilson, Sinclair Daniel,...
# 2  [Jennifer Lawrence, Andrew Barth Feldman, Laur...
# 3  [Shameik Moore, Hailee Steinfeld, Jason Schwar...
# 4  [Jason Schwartzman, Scarlett Johansson, Tom Ha...
#
#                                                 Crew  \
# 0                                     [Greta Gerwig]
# 1                                   [Patrick Wilson]
# 2                                  [Gene Stupnitsky]
# 3  [Joaquim Dos Santos, Justin K. Thompson, Kemp ...
# 4                                     [Wes Anderson]
#
#                                              Studios  \
# 0  [LuckyChap Entertainment, Heyday Films, NB/GG ...
# 1  [Blumhouse Productions, Stage 6 Films, Screen ...
# 2  [Excellent Cadaver, Odenkirk Provissiero Enter...
# 3  [Columbia Pictures, Sony Pictures Animation, L...
# 4   [American Empirical Pictures, Indian Paintbrush]
#
#                                               Genres
# 0  [fantasy, comedy, adventure, Relationship come...
# 1  [thriller, horror, mystery, Horror, the undead...
# 2  [comedy, romance, Relationship comedy, Crude h...
# 3  [animation, adventure, action, Epic heroes, ac...
# 4  [comedy, drama, Relationship comedy, earth, sc...

# %%
df.shape
# Out:
# (2401, 8)

# %%
import json

df['Cast'] = df['Cast'].apply(json.dumps)
df['Crew'] = df['Crew'].apply(json.dumps)
df['Studios'] = df['Studios'].apply(json.dumps)
df['Genres'] = df['Genres'].apply(json.dumps)

# Save DataFrame to CSV
df.to_csv(f'{username}_ratings.csv')
